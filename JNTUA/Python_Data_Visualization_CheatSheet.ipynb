# %% [markdown]
# # Python Data Visualization Cheat Sheet – Matplotlib & Seaborn
# This cheat sheet covers **Matplotlib** and **Seaborn** for **data visualization**, including major plots, syntax, explanations, and color palettes.
#
# ---

# %% [markdown]
# ## 🔹 Matplotlib – Basic Plots

# %% [markdown]
# ### **1️⃣ Line Plot 📈**
# 🔹 **Used for** visualizing trends over time.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

plt.plot(x, y, marker='o', linestyle='-', color='m', label='Trend')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot Example')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### **2️⃣ Bar Plot 📊**
# 🔹 **Used for** comparing categorical data.

# %%
categories = ['A', 'B', 'C', 'D']
values = [10, 25, 17, 30]

plt.bar(categories, values, color='skyblue', edgecolor='black')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Plot Example')
plt.show()

# %% [markdown]
# ### **3️⃣ Scatter Plot 🔵**
# 🔹 **Used for** visualizing relationships between variables.

# %%
import numpy as np

x = np.random.rand(50)
y = np.random.rand(50)

plt.scatter(x, y, color='red', marker='x')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot Example')
plt.show()

# %% [markdown]
# ### **4️⃣ Histogram 📊**
# 🔹 **Used for** showing frequency distributions.

# %%
data = np.random.randn(1000)

plt.hist(data, bins=20, color='blue', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Example')
plt.show()

# %% [markdown]
# ### **5️⃣ Pie Chart 🍕**
# 🔹 **Used for** displaying proportions.

# %%
labels = ['A', 'B', 'C', 'D']
sizes = [25, 35, 20, 20]
colors = ['gold', 'lightblue', 'lightgreen', 'pink']

plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Pie Chart Example')
plt.show()

# %% [markdown]
# ### **6️⃣ Box Plot 📦**
# 🔹 **Used for** showing data distribution and detecting outliers.

# %%
data = [np.random.randn(100), np.random.randn(100) + 2, np.random.randn(100) - 2]

plt.boxplot(data, labels=['A', 'B', 'C'])
plt.xlabel('Category')
plt.ylabel('Values')
plt.title('Box Plot Example')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2876\822631928.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=['A', 'B', 'C'])

# %% [markdown]
# ## 🔹 Seaborn – Advanced Plots

# %% [markdown]
# ### **1️⃣ Seaborn Line Plot**
# 🔹 **Used for** trends with confidence intervals.

# %%
import seaborn as sns
import pandas as pd

data = pd.DataFrame({'x': range(10), 'y': [i + (i%3) for i in range(10)]})
sns.lineplot(x='x', y='y', data=data, marker='o')

plt.title('Seaborn Line Plot')
plt.show()

# %% [markdown]
# ### **2️⃣ Seaborn Bar Plot**
# 🔹 **Used for** categorical comparisons.

# %%
sns.barplot(x=['A', 'B', 'C', 'D'], y=[10, 25, 17, 30], palette='coolwarm')
plt.title('Seaborn Bar Plot')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2876\2433668655.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['A', 'B', 'C', 'D'], y=[10, 25, 17, 30], palette='coolwarm')

# %% [markdown]
# ### **3️⃣ Seaborn Heatmap 🔥**
# 🔹 **Used for** showing relationships in matrices.

# %%
data = np.random.rand(5, 5)
sns.heatmap(data, annot=True, cmap='coolwarm')
plt.title('Seaborn Heatmap')
plt.show()

# %% [markdown]
# # **All Plots**
# | Plot Type       | **Matplotlib Function** | **Seaborn Function** |
# |----------------|----------------|----------------|
# | **Line Plot** | `plt.plot()` | `sns.lineplot()` |
# | **Bar Chart** | `plt.bar()` | `sns.barplot()` |
# | **Scatter Plot** | `plt.scatter()` | `sns.scatterplot()` |
# | **Histogram** | `plt.hist()` | `sns.histplot()` |
# | **Pie Chart** | `plt.pie()` | (Matplotlib only) |
# | **Box Plot** | `plt.boxplot()` | `sns.boxplot()` |
# | **Heatmap** | `sns.heatmap()` | `sns.heatmap()` |
#
# ---
# ✅ **Matplotlib** is great for static visualizations, while **Seaborn** enhances aesthetics.
# ✅ **Use colormaps & color palettes** to improve visualization.
# ✅ **Choose Seaborn for more elegant, readable charts.**
