# %% [markdown]
# ---
#
# ### **1️⃣ The Messy Customer Orders at Mumbai E-Mart** 🛒
# A popular e-commerce store in Mumbai is struggling with **duplicate orders, incorrect phone numbers, and inconsistent payment statuses** in their sales records. Some orders appear twice with different IDs, some phone numbers are missing digits, and payment statuses are mixed (e.g., "Paid", "Success", "Completed").
#
# **Students must:**
# - Remove duplicate orders.
# - Fix inconsistent payment statuses.
# - Validate and clean phone numbers.
#
# ---
#
# ### **2️⃣ The Indian Railway Passenger Data Cleanup** 🚆
# Indian Railways maintains a database of passenger bookings, but there are **missing genders, wrongly formatted travel dates, and duplicate ticket numbers**. Some passenger ages are also unrealistic (e.g., 200 years old).
#
# **Students must:**
# - Standardize travel dates.
# - Fix incorrect or missing gender entries.
# - Remove duplicate or illogical age values.
#
# ---
#
# ### **3️⃣ Restaurant Ratings and Reviews Cleanup in Zomato Data** 🍽️
# A restaurant aggregator platform has a dataset with **user reviews, restaurant categories, and pricing details**. However, there are multiple issues: some restaurants have **multiple categories (e.g., "North Indian, SouthIndian" vs. "North-Indian, South Indian")**, some reviews contain **duplicate texts**, and pricing is missing for certain restaurants.
#
# **Students must:**
# - Clean and standardize restaurant categories.
# - Remove duplicate or spam reviews.
# - Handle missing pricing data.
#
# ---
#
# ### **4️⃣ Banking Transactions Cleanup for RBI Audit** 💰
# A bank needs to **audit its transactions**, but the data is a mess. Some **IFSC codes are missing, transaction timestamps are in different formats**, and transaction amounts have negative values where they shouldn’t.
#
# **Students must:**
# - Standardize transaction timestamps.
# - Fix missing or incorrect IFSC codes.
# - Correct transaction amounts where needed.
#
# ---
#
# ### **5️⃣ Messy IPL Player Statistics Cleanup** 🏏
# The Indian Premier League (IPL) maintains records of players' performances, but the data has **inconsistent team names, missing player nationalities, and wrongly formatted match dates**. Some players appear under different names due to spelling variations (e.g., "Virat Kohli" vs. "V Kohli").
#
# **Students must:**
# - Standardize team names.
# - Fill missing player nationalities.
# - Fix inconsistent player names.
#
# ---
#
# ### **6️⃣ Student Attendance & Marks Data Standardization** 🎓
# A university has attendance and marks data for students, but the dataset has issues: some student names appear **with extra spaces or different spellings**, subjects are **listed differently (e.g., "Maths" vs. "Mathematics")**, and some attendance values are negative or above 100%.
#
# **Students must:**
# - Clean student names for consistency.
# - Standardize subject names.
# - Correct unrealistic attendance values.
#
# ---
#
# ### **7️⃣ Indian Mobile Recharge Data Cleanup** 📱
# A telecom company has customer recharge records, but the dataset contains **invalid mobile numbers, missing recharge amounts, and inconsistent plan names** (e.g., "Jio 399" vs. "399 Jio Plan").
#
# **Students must:**
# - Validate and clean mobile numbers.
# - Handle missing recharge amounts.
# - Standardize plan names.
#
# ---
#
# ### **8️⃣ Toll Booth Data Cleanup for National Highways** 🚗
# The government wants to analyze toll collection data, but the dataset has **duplicate vehicle numbers, inconsistent timestamps, and missing toll amounts** for some vehicles.
#
# **Students must:**
# - Remove duplicate vehicle entries.
# - Standardize timestamp formats.
# - Fill missing toll amounts logically.
#
# ---
#
# ### **9️⃣ Election Voter List Data Cleanup** 🗳️
# A political party wants to analyze voter demographics, but the dataset has **incomplete addresses, missing voter IDs, and inconsistent state names (e.g., "UP" vs. "Uttar Pradesh")**.
#
# **Students must:**
# - Standardize state names.
# - Handle missing voter IDs.
# - Fix incomplete addresses.
#
# ---
#
# ### **🔟 Movie Ticket Sales & Audience Data Cleanup** 🎬
# A cinema chain has ticket sales data, but the dataset has **mismatched seat numbers, missing audience age details, and inconsistent theater names** (e.g., "PVR Cinemas" vs. "PVR").
#
# **Students must:**
# - Standardize theater names.
# - Correct mismatched seat numbers.
# - Fill missing audience age details.
#
# ---
#
# ### **1️⃣1️⃣ Indian Weather Data Cleanup for Climate Study** ☀️🌧️
# Meteorologists are analyzing climate data, but the dataset has **missing temperature values, inconsistent date formats, and duplicate city names (e.g., "Bangalore" vs. "Bengaluru")**.
#
# **Students must:**
# - Standardize city names.
# - Handle missing temperature values.
# - Convert date formats to a standard form.
#
# ---
#
# ### **1️⃣2️⃣ Hospital Patient Records Cleanup** 🏥
# A hospital maintains patient records, but there are **duplicate patient IDs, missing discharge dates, and inconsistent disease names** (e.g., "Covid" vs. "COVID-19").
#
# **Students must:**
# - Remove duplicate patient IDs.
# - Handle missing discharge dates.
# - Standardize disease names.
#
# ---
#
# ### **Now, Select Your Final 6!** 🎯
# Each problem covers **multiple columns**, ensuring a **real-world challenge** for your students. Pick **6 from these 12**, and I’ll refine them into **detailed problem statements with datasets** for your workshop. 🚀
